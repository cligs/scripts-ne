# %% [markdown]
# # Chapter 3.2. Metadata

# %%
import sys
import os
sys.path.append(os.path.abspath("//home/jose/Dropbox/Doktorarbeit/"))
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
from reading_robot import describe_data, load_data, cull_data, metadata2numbers, st_tests, get_metadata

# %% [markdown]
# # 3.2.0. Getting Data

# %%
get_metadata.from_TEIP5("/home/jose/Dropbox/Doktorarbeit/novelasespanolas/","master/*.xml","metadata","beta-opt-obl-structure")
# Out:
# Metadata extracted. Number of documents and metadata columns: (358, 173)
#           idno     author.name               title  year   supergenre   genre  \
# ne0001  ne0001          Baroja           Mayorazgo  1903    narrative  novela
# ne0002  ne0002          Galdos        Misericordia  1889    narrative  novela
# ne0003  ne0003          Galdos             Nazarin  1895    narrative  novela
# ne0004  ne0004          Galdos               Halma  1895    narrative  novela
# ne0005  ne0005          Galdos            Tristana  1892    narrative  novela
# ne0006  ne0006          Galdos               Angel  1891    narrative  novela
# ne0007  ne0007            Sawa          MujerMundo  1885    narrative  novela
# ne0008  ne0008        Zamacois             Enferma  1896    narrative  novela
# ne0009  ne0009          Galdos         Desheredada  1881    narrative  novela
# ne0010  ne0010        Aparicio             Vicario  1905    narrative  novela
# ...

# %%
metadata2numbers.recategorize_metadata()
# Out:
# metadata and class shape: 	 (358, 173)
# author.continent
# author.country
# author.gender
# author.movement
# author.submovement
# author.date.birth
# author.date.death
# author.litHist.pages
# author.nonNovelGenre
# authorText.relation
# authorText.group
# authorText.subgroup
# form
# publication
# text.movement
# litHist.brow
# litHist.pages
# genre
# supergenre
# narrator
# setting.continent
# setting.country
# setting.territory
# setting.settlement
# setting.type
# setting.settlement.represented.exist
# setting.represented
# time.period
# time.span
# time.year
# protagonist.name
# protagonist.profession
# protagonist.age
# protagonist.gender
# protagonist.socLevel
# end
# representation
# (358, 183)
#           idno     author.name               title  year   supergenre   genre  \
# ne0001  ne0001          Baroja           Mayorazgo  1903    narrative  novela
# ne0002  ne0002          Galdos        Misericordia  1889    narrative  novela
# ...

# %%
from shutil import copyfile

copyfile("/home/jose/cligs/ne/population_authors.csv", "/home/jose/Dropbox/Doktorarbeit/thesis/data/population_authors.csv")
copyfile("/home/jose/cligs/ne/metadata_beta-opt-obl-structure.csv", "/home/jose/Dropbox/Doktorarbeit/thesis/data/metadata_beta-opt-obl-structure.csv")
copyfile("/home/jose/cligs/ne/metadata_recategorized.csv", "/home/jose/Dropbox/Doktorarbeit/thesis/data/metadata_recategorized.csv")
# Out:
# '/home/jose/Dropbox/Doktorarbeit/thesis/data/metadata_recategorized.csv'

# %%
metadata = load_data.load_metadata(wdir ="/home/jose/Dropbox/Doktorarbeit/thesis/data/", metadata_table = "metadata_beta-opt-obl-structure.csv", sep = ",").fillna("")
metadata_recategorized = load_data.load_metadata(wdir ="/home/jose/Dropbox/Doktorarbeit/thesis/data/", metadata_table = "metadata_recategorized.csv", sep = "\t")
# Out:
# metadata and class shape: 	 (358, 173)
# metadata and class shape: 	 (358, 183)

# %%
metadata.columns.values
# Out:
# array(['idno', 'author.name', 'title', 'year', 'supergenre', 'genre',
#        'subgenre.cligs.important', 'author.country', 'author.viaf',
#        'author.bne', 'author.gender', 'title.main', 'title.viaf',
#        'title.bne', 'author.name.full', 'subtitle', 'availability',
#        'subgenre.cligs', 'date.file', 'digital.source',
#        'digital.source.format', 'genre.subtitle', 'narrator',
#        'protagonist.gender', 'setting.type', 'form', 'publication',
#        'digital.source.idno', 'author.continent', 'authorText.group',
#        'authorText.subgroup', 'protagonist.name', 'protagonist.age',
#        'protagonist.socLevel', 'protagonist.profession', 'representation',
#        'setting.continent', 'setting.country', 'setting.settlement',
#        'setting.territory', 'text.movement', 'time.period', 'time.span',
#        'authorText.relation', 'end', 'time.year', 'keywords.cert',
#        'author.movement', 'author.submovement', 'author.date.birth',
# ...

# %%
metadata_recategorized.columns.values
# Out:
# array(['idno', 'author.name', 'title', 'year', 'supergenre', 'genre',
#        'subgenre.cligs.important', 'author.country', 'author.viaf',
#        'author.bne', 'author.gender', 'title.main', 'title.viaf',
#        'title.bne', 'author.name.full', 'subtitle', 'availability',
#        'subgenre.cligs', 'date.file', 'digital.source',
#        'digital.source.format', 'genre.subtitle', 'narrator',
#        'protagonist.gender', 'setting.type', 'form', 'publication',
#        'digital.source.idno', 'author.continent', 'authorText.group',
#        'authorText.subgroup', 'protagonist.name', 'protagonist.age',
#        'protagonist.socLevel', 'protagonist.profession', 'representation',
#        'setting.continent', 'setting.country', 'setting.settlement',
#        'setting.territory', 'text.movement', 'time.period', 'time.span',
#        'authorText.relation', 'end', 'time.year', 'keywords.cert',
#        'author.movement', 'author.submovement', 'author.date.birth',
# ...

# %%
set(metadata["supergenre"])
# Out:
# {'mixed', 'narrative', 'non-fiction'}

# %%
set(metadata["genre"])
# Out:
# {'?', 'greguerías', 'novela'}

# %%
len(set(metadata["genre.subtitle"]))
# Out:
# 47

# %%
len(set(metadata["subgenre.subtitle.bne"]))
# Out:
# 64

# %%
len(set(metadata["subgenre.lithist.MdLE"]))
# Out:
# 78

# %%
len(set(metadata["subgenre.lithist.HdLE"]))
# Out:
# 34

# %%
wdir = "/home/jose/Dropbox/Doktorarbeit/thesis/data/chap3_2/"

# %% [markdown]
# # 3.2.8. Place and Period of the Action

# %%
metadata.loc[metadata["setting.territory"] == "mixed"].sort_values(by="litHist.pages", ascending = False).head()
# Out:
#           idno author.name         title  year supergenre   genre  \
# ne0068  ne0068      Baroja  ArbolCiencia  1911  narrative  novela
# ne0121  ne0121      Azorin      Voluntad  1902  narrative  novela
# ne0116  ne0116      Baroja        Camino  1902  narrative  novela
# ne0394  ne0394     RPAyala    PataRaposa  1912  narrative  novela
# ne0037  ne0037       Valle    MediaNoche  1917  narrative       ?
#
#        subgenre.cligs.important author.country  author.viaf author.bne  ...    \
# ne0068            bildungsroman          Spain  3.69129e+07   XX842743  ...
# ne0121            philosophical          Spain  2.47976e+06   XX825215  ...
# ne0116            bildungsroman          Spain  3.69129e+07   XX842743  ...
# ne0394            bildungsroman          Spain  1.23203e+07   XX982844  ...
# ne0037               historical          Spain  6.89368e+07  XX1055436  ...
#
#        am.wnlex.noun.Topss am.wnlex.noun.relations am.wnlex.noun.attributes  \
# ...

# %%
metadata.loc[metadata["setting.country"] == "mixed"].sort_values(by="litHist.pages", ascending = False).head()
# Out:
#           idno author.name       title  year supergenre   genre  \
# ne0394  ne0394     RPAyala  PataRaposa  1912  narrative  novela
# ne0111  ne0111      Baroja        Ansi  1912  narrative  novela
# ne0136  ne0136      Azorin    DonaInes  1925  narrative  novela
# ne0151  ne0151      Valera       Genio  1897  narrative  novela
# ne0153  ne0153      Valera    Morsamor  1899  narrative  novela
#
#        subgenre.cligs.important author.country  author.viaf author.bne  ...    \
# ne0394            bildungsroman          Spain  1.23203e+07   XX982844  ...
# ne0111            bildungsroman          Spain  3.69129e+07   XX842743  ...
# ne0136              sentimental          Spain  2.47976e+06   XX825215  ...
# ne0151            bildungsroman          Spain  4.67706e+07   XX918093  ...
# ne0153                fantastic          Spain  4.67706e+07   XX918093  ...
#
#        am.wnlex.noun.Topss am.wnlex.noun.relations am.wnlex.noun.attributes  \
# ...

# %%
metadata.loc[metadata["setting.continent"] == "mixed"].sort_values(by="litHist.pages", ascending = False).head()
# Out:
#           idno   author.name        title  year supergenre   genre  \
# ne0136  ne0136        Azorin     DonaInes  1925  narrative  novela
# ne0151  ne0151        Valera        Genio  1897  narrative  novela
# ne0153  ne0153        Valera     Morsamor  1899  narrative  novela
# ne0038  ne0038       RBaroja  NaoCapitana  1935  narrative  novela
# ne0165  ne0165  BlascoIbanez  Apocalipsis  1916  narrative  novela
#
#        subgenre.cligs.important author.country  author.viaf author.bne  ...    \
# ne0136              sentimental          Spain  2.47976e+06   XX825215  ...
# ne0151            bildungsroman          Spain  4.67706e+07   XX918093  ...
# ne0153                fantastic          Spain  4.67706e+07   XX918093  ...
# ne0038                adventure          Spain  7.42759e+06             ...
# ne0165               historical          Spain  7.38481e+07  XX1028057  ...
#
#        am.wnlex.noun.Topss am.wnlex.noun.relations am.wnlex.noun.attributes  \
# ...

# %%
metadata.loc[metadata["setting.settlement.represented.exist"] == False].sort_values(by="litHist.pages", ascending = False)
# Out:
#           idno   author.name               title  year supergenre   genre  \
# ne0048  ne0048          Miro             Cerezas  1910  narrative  novela
# ne0130  ne0130       Ganivet                Maya  1897  narrative  novela
# ne0276  ne0276        Galdos              Abuelo  1897  narrative  novela
# ne0401  ne0401     Verdaguer  IntelectualCarcoma  1934  narrative  novela
# ne0159  ne0159         Trigo       Jarrapellejos  1914  narrative  novela
# ne0381  ne0381        Jarnes         LocuraNadie  1929  narrative  novela
# ne0380  ne0380      Espinosa              Crimen  1934  narrative  novela
# ne0235  ne0235        Baroja                Cura  1936  narrative  novela
# ne0250  ne0250        Galdos               Razon  1915  narrative  novela
# ne0379  ne0379        Azorin             DonJuan  1922  narrative  novela
# ne0365  ne0365      WFFlorez           BarbaAzul  1923  narrative  novela
# ne0370  ne0370      WFFlorez      NoFuimosGuerra  1930  narrative  novela
# ...

# %%
len(list(set(metadata["protagonist.profession"])))
# Out:
# 31

# %%
len(list(set(metadata["protagonist.socLevel"])))
# Out:
# 6

# %%
list(set(metadata["protagonist.socLevel"]))
# Out:
# ['?', 'medium', 'other', 'high', 'unknown', 'low']

# %%
len(list(set(metadata["protagonist.age"])))
# Out:
# 7

# %%
list(set(metadata["protagonist.age"]))
# Out:
# ['?', 'adult', 'other', 'unknown', 'mature', 'child', 'young']

# %%
list(set(metadata["narrator"]))
# Out:
# ['mixed',
#  'homodiegetic',
#  'other',
#  'autodiegetic',
#  'epistolary',
#  'heterodiegetic',
#  'dialogue']

# %%
list(set(metadata["representation"]))
# Out:
# ['non-realistic', 'neutral', 'realistic']

# %%
list(set(metadata["litHist.literaryQuality"]))
# Out:
# ['', 'medium', 'low', 'high']

# %% [markdown]
# # 3.2.11. Description of the Metadata of CoNSSA

# %%
central_tendencies = metadata2numbers.analyze_central_tendencies(metadata_recategorized)

# %%
central_tendencies
# Out:
#                                  keyword class_type  \
# 0                       author.continent    nominal
# 1                         author.country    nominal
# 5                      author.date.birth   interval
# 6                      author.date.death   interval
# 2                          author.gender    nominal
# 7                   author.litHist.pages      ratio
# 3                        author.movement    ordinal
# 8                   author.nonNovelGenre    nominal
# 4                     author.submovement    ordinal
# 10                      authorText.group    nominal
# 9                    authorText.relation    ordinal
# 11                   authorText.subgroup    nominal
# 35                                   end    ordinal
# 12                                  form    nominal
# 17                                 genre    nominal
# 15                          litHist.brow    ordinal
# 16                         litHist.pages      ratio
# ...

# %%
metadata_recategorized_canon = metadata_recategorized.loc[metadata_recategorized["CoNSSA.canon"] == True]
central_tendencies_canon = metadata2numbers.analyze_central_tendencies(metadata_recategorized_canon)

# %%
central_tendencies_canon
# Out:
#                                  keyword class_type  \
# 0                       author.continent    nominal
# 1                         author.country    nominal
# 5                      author.date.birth   interval
# 6                      author.date.death   interval
# 2                          author.gender    nominal
# 7                   author.litHist.pages      ratio
# 3                        author.movement    ordinal
# 8                   author.nonNovelGenre    nominal
# 4                     author.submovement    ordinal
# 10                      authorText.group    nominal
# 9                    authorText.relation    ordinal
# 11                   authorText.subgroup    nominal
# 35                                   end    ordinal
# 12                                  form    nominal
# 17                                 genre    nominal
# 15                          litHist.brow    ordinal
# 16                         litHist.pages      ratio
# ...

# %%
metadata_recategorized.loc[
(metadata_recategorized["narrator"] == "heterodiegetic" ) &
(metadata_recategorized["author.gender"] == "male") &
(metadata_recategorized["protagonist.gender"] == "male") &
(metadata_recategorized["protagonist.socLevel"] == "medium") &
(metadata_recategorized["protagonist.age"] == "adult") &
(metadata_recategorized["setting.continent"] == "Europe") &
(metadata_recategorized["setting.country"] == "Spain") &
(metadata_recategorized["setting.represented"] == "Madrid") & 
(metadata_recategorized["time.period"] == "contemporary") &  
(metadata_recategorized["representation"] == "realistic")  & 
(metadata_recategorized["authorText.relation"] == "none")  & 
(metadata_recategorized["time.span"] == "365") & 
(metadata_recategorized["end"] == "negative")      
    
][["author.name","title.main","year","CoNSSA.canon"]]
# Out:
#        author.name               title.main  year  CoNSSA.canon
# ne0229      Valdes  Tristán  o el pesimismo  1906          True

# %%
metadata_recategorized.loc[
(metadata_recategorized["narrator"] == "heterodiegetic" ) &
(metadata_recategorized["author.gender"] == "male") &
(metadata_recategorized["protagonist.gender"] == "male") &
(metadata_recategorized["protagonist.socLevel"] == "medium") &
(metadata_recategorized["protagonist.age"] == "adult") &
(metadata_recategorized["setting.continent"] == "Europe") &
(metadata_recategorized["setting.country"] == "Spain") &
(metadata_recategorized["time.period"] == "contemporary") &  
(metadata_recategorized["representation"] == "realistic")  & 
(metadata_recategorized["authorText.relation"] == "none")  &  
(metadata_recategorized["end"] == "negative")      
    
][["author.name","title.main","year"]].sort_values(by="author.name")
# Out:
#          author.name                              title.main  year
# ne0176       Alarcon                              La pródiga  1882
# ne0238        Baroja               La feria de los discretos  1905
# ne0248        Baroja                         Los visionarios  1932
# ne0255  BlascoIbanez                           Cañas y barro  1902
# ne0261  BlascoIbanez                            Luna Benamor  1909
# ne0331        FAyala  Tragicomedia de un hombre sin espíritu  1925
# ne0381        Jarnes                Locura y muerte de Nadie  1929
# ne0290         Lanza                             Los gusanos  1909
# ne0201          Leon                                   Jauja  1928
# ne0041          Miro                       Hilván de escenas  1903
# ne0045          Miro                           La palma rota  1909
# ne0052          Miro                       El abuelo del rey  1915
# ne0384       Munilla                           Don Juan Solo  1880
# ...

# %%
metadata_recategorized["amount_unknown"] = metadata_recategorized.T.apply(pd.Series.value_counts).loc["unknown"].fillna(0)

# %%
metadata_recategorized.plot.scatter("year","amount_unknown")

# %%
import scipy.stats as stats
stats.linregress(metadata_recategorized["year"], metadata_recategorized["amount_unknown"])
# Out:
# LinregressResult(slope=0.0042109409923618436, intercept=-7.793664929887642, rvalue=0.08013514223530353, pvalue=0.13018820766999625, stderr=0.0027760814646852427)

# %%
stats.linregress(metadata_recategorized.loc[metadata_recategorized["CoNSSA.canon"] == True]["year"], metadata_recategorized.loc[metadata_recategorized["CoNSSA.canon"] == True]["amount_unknown"])
# Out:
# LinregressResult(slope=0.003711933760318909, intercept=-6.93753356845482, rvalue=0.11287897893620881, pvalue=0.18744223465419013, stderr=0.002801773968269355)

# %%
root = metadata2numbers.open_keywords()
category_df = metadata2numbers.get_values_names_keywords(root, "authorText.relation")

# %%
dataset = "CoNSSA"

# %%
metadata_recategorized.loc[(metadata_recategorized["decade"] == 1880) & (metadata_recategorized["authorText.relation"] == "none")].shape[0] / metadata_recategorized.loc[metadata_recategorized["decade"] == 1880].shape[0] * 100
# Out:
# 86.0

# %%
metadata_recategorized.loc[(metadata_recategorized["decade"] == 1930) & (metadata_recategorized["authorText.relation"] == "none")].shape[0] / metadata_recategorized.loc[metadata_recategorized["decade"] == 1880].shape[0] * 100
# Out:
# 57.99999999999999

# %%
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized,
class_1 = "decade", class_2 = "authorText.relation_ordinal", dataset = dataset, in_proportions=True,
                                          legend = category_df["name"].tolist())
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
stats.linregress(metadata_recategorized["authorText.relation_ordinal"], metadata_recategorized["year"])
# Out:
# LinregressResult(slope=2.853461238583201, intercept=1908.7763839385163, rvalue=0.1836862161434355, pvalue=0.00047741386724050276, stderr=0.8093144052376632)

# %%
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized_canon,
class_1 = "decade", class_2 = "authorText.relation_ordinal", dataset = "CoNSSA-canon", in_proportions=True,
                                          legend = category_df["name"].tolist())
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
stats.linregress(metadata_recategorized_canon["authorText.relation_ordinal"], metadata_recategorized_canon["year"])
# Out:
# LinregressResult(slope=4.510226644555007, intercept=1903.1310116086236, rvalue=0.2927189890053079, pvalue=0.0004939317248284226, stderr=1.2633569646856522)

# %%
geo_classes = ["setting.represented"]
filter_class = {}
metadata_existingplaces = metadata2numbers.setting_string2geo(wdir, metadata_recategorized, geo_classes, filter_class)
# Out:
# {}
# setting.represented
# ne0001 Labraz
# ne0002 Madrid
# //home/jose/Dropbox/Doktorarbeit/reading_robot/metadata2numbers.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   metadata_existingplaces["Longitude"][index] = (df_geoplaces.loc[df_geoplaces['location'] == row[class_], "lon"].values[0])
# //home/jose/Dropbox/Doktorarbeit/reading_robot/metadata2numbers.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   metadata_existingplaces["Latitude"][index] = (df_geoplaces.loc[df_geoplaces['location'] == row[class_],"lat"].values[0])
# ne0003 Castilla
# ne0004 Madrid
# ne0005 Madrid
# ne0006 Toledo
# ne0007 Madrid
# ne0008 Madrid
# ...

# %%
results = st_tests.calculate_regression(metadata_recategorized, "setting.type_ordinal", "year")
results
# Out:
# (358, 184)
# (340, 184)
# LinregressResult(slope=-1.041227318454492, intercept=1912.1664741607362, rvalue=-0.060830125084342164, pvalue=0.26332896555147056, stderr=0.9293161687626267)

# %%
results = st_tests.calculate_regression(metadata_recategorized, "authorText.relation_ordinal", "year")
results
# Out:
# (358, 184)
# (358, 184)
# LinregressResult(slope=2.853461238583201, intercept=1908.7763839385163, rvalue=0.1836862161434355, pvalue=0.00047741386724050276, stderr=0.8093144052376632)

# %%
category_df = metadata2numbers.get_values_names_keywords(root, "setting.type")
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized,
class_1 = "decade", class_2 = "setting.type_ordinal", dataset = "CoNNSA", in_proportions=True,
                                          legend = category_df["name"].tolist(), loc_legend = "upper left")
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
category_df = metadata2numbers.get_values_names_keywords(root, "setting.type")
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized_canon,
class_1 = "decade", class_2 = "setting.type_ordinal", dataset = "CoNSSA-canon", in_proportions=True,
                                          legend = category_df["name"].tolist(), loc_legend = "upper left")
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
category_df = metadata2numbers.get_values_names_keywords(root, "time.period")
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized,
class_1 = "decade", class_2 = "time.period_ordinal", dataset = "CoNSSA", in_proportions=True,
                                          legend = category_df["name"].tolist())
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
metadata_recategorized.loc[metadata_recategorized["time.period"] == "contemporary"].shape[0]/metadata_recategorized.shape[0]
# Out:
# 0.9413407821229051

# %%
metadata_recategorized_canon.loc[metadata_recategorized_canon["time.period"] == "contemporary"].shape[0]/metadata_recategorized_canon.shape[0]
# Out:
# 0.9637681159420289

# %%
metadata_recategorized.loc[(metadata_recategorized["time.period"] == "contemporary") & (metadata_recategorized["decade"] == 1910)].shape[0]/metadata_recategorized.loc[metadata_recategorized["decade"] == 1910].shape[0]
# Out:
# 0.8787878787878788

# %%
metadata_recategorized_culled = cull_data.cull_metadata(metadata_recategorized.fillna("n.av."), 'time.span', problematic_values = ["?","n.av.", None, "unknown","other","mixed"])
metadata_recategorized_culled["time.span"] = pd.to_numeric(metadata_recategorized_culled["time.span"])
metadata_recategorized_culled_cut = metadata_recategorized_culled.loc[(metadata_recategorized_culled['time.span'] < 5475)].copy()
dataset = "CoNSSA (time.span < 5475 days, 5 years)"
describe_data.simple_boxplot(metadata = metadata_recategorized_culled_cut, classes = ["time.span"], wdir = wdir, dataset = dataset, ylabel ="days")
describe_data.histogram(metadata = metadata_recategorized_culled_cut, class_ = "time.span", wdir = wdir, dataset = dataset, kind ="normal", bins=[1,7,30,90,120,365,730,1095,2000,4000,6000])
describe_data.histogram(metadata = metadata_recategorized_culled_cut, class_ = "time.span", wdir = wdir, dataset = dataset, kind ="normal")
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
print(metadata_recategorized_culled["time.span"].median(),
      metadata_recategorized_culled["time.span"].mode(),
stats.iqr(metadata_recategorized_culled["time.span"]),
     metadata_recategorized_culled["time.span"].min(),
     metadata_recategorized_culled["time.span"].max(),
     metadata_recategorized_culled["time.span"].max()/365)
# Out:
# 365.0 0    365
# dtype: int64 795.0 1 25550 70.0

# %%
metadata_recategorized_culled.loc[metadata_recategorized_culled["time.span"] == 1][["title.main","author.name"]]
# Out:
#                     title.main author.name
# ne0037          La media noche       Valle
# ne0091   Eufrosina o la gracia      Jarnes
# ne0181  La velada en Benicarló       Azana
# ne0299         Pachín González      Pereda

# %%
metadata_recategorized_culled.loc[metadata_recategorized_culled["time.span"] > 20000][["title.main","author.name"]]
# Out:
#                                     title.main author.name
# ne0069                            Abel Sánchez     Unamuno
# ne0115  Aviraneta: o la vida de un conspirador      Baroja
# ne0304         Las inquietudes de Shanti Andía      Baroja
# ne0365                El secreto de Barba Azul    WFFlorez

# %%
describe_data.describe_corpus_scatter(metadata = metadata_recategorized_culled_cut, wdir = wdir, class_1 = "time.span", class_2 = "am.tokens", dataset = "CoNSSA" , fit_reg=True)
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py:830: MatplotlibDeprecationWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   mplDeprecation)

# %%
stats.linregress(metadata_recategorized_culled_cut["time.span"], metadata_recategorized_culled_cut["am.tokens"])
# Out:
# LinregressResult(slope=3.0404932859922935, intercept=61246.769253000275, rvalue=0.08339871941474974, pvalue=0.16026164279385063, stderr=2.1596125254784235)

# %%
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized_canon,
class_1 = "decade", class_2 = "protagonist.gender", dataset = "CoNSSA-canon", in_proportions= True,
                                          problematic_values = []
                                          )
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized,
class_1 = "decade", class_2 = "protagonist.gender", dataset = "CoNSSA", in_proportions= True,
                                          problematic_values = []
                                          )
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
contingency_table = pd.crosstab(metadata["author.gender"], metadata["protagonist.gender"])[["female","male"]]

# %%
contingency_table
# Out:
# protagonist.gender  female  male
# author.gender
# female                  12    17
# male                    64   259

# %%
contingency_table.loc["female"] = contingency_table.loc["female"] / contingency_table.loc["female"].sum()*100

# %%
contingency_table.loc["male"] = contingency_table.loc["male"] / contingency_table.loc["male"].sum()*100

# %%
contingency_table.round(2)
# Out:
# protagonist.gender     female       male
# author.gender
# female              41.379310  58.620690
# male                19.814241  80.185759

# %%
stats.chisquare(contingency_table[["female","male"]])
# Out:
# Power_divergenceResult(statistic=array([7.59969279, 3.35036449]), pvalue=array([0.00583782, 0.06719013]))

# %%
stats.chi2_contingency(contingency_table[["female","male"]])
# Out:
# (9.958066650168053,
#  0.0016014614193213806,
#  1,
#  array([[30.59677592, 69.40322408],
#         [30.59677592, 69.40322408]]))

# %%
metadata_recategorized.loc[(metadata_recategorized["decade"].isin([1880,1890])) & (metadata_recategorized["protagonist.gender"] == "female")].shape[0]  / metadata_recategorized.loc[metadata_recategorized["decade"].isin([1880,1890])].shape[0]
# Out:
# 0.38613861386138615

# %%
metadata_recategorized.loc[(metadata_recategorized["decade"].isin([1900,1910,1920,1930])) & (metadata_recategorized["protagonist.gender"] == "female")].shape[0]  / metadata_recategorized.loc[metadata_recategorized["decade"].isin([1900,1910,1920,1930])].shape[0]
# Out:
# 0.14396887159533073

# %%
set(metadata_recategorized_canon["end_ordinal"].astype(int))
# Out:
# {0, 1, 2, 3, 4}

# %%
classes = ["end_ordinal", "protagonist.age_ordinal","protagonist.socLevel_ordinal","setting.type_ordinal"]
class_by = "protagonist.gender"
class_by_values = ["male","female"]
describe_data.independent_boxplots_by_class(metadata_recategorized, classes, class_by, class_by_values,  wdir, "CoNSSA", has_title=True)
# Out:
# /usr/local/lib/python3.4/dist-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
Counter(metadata_recategorized["end"])
# Out:
# Counter({'?': 7,
#          'negative': 178,
#          'neutral': 60,
#          'partial negative': 34,
#          'partial positive': 19,
#          'positive': 60})

# %%
category_df = metadata2numbers.get_values_names_keywords(root, "end")
print(category_df)
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized,
class_1 = "decade", class_2 = "end_ordinal", dataset = "CoNSSA", in_proportions= True,
                                          legend = category_df["name"].tolist())
# Out:
#   value              name
# 0     0          negative
# 1     1  partial negative
# 2     2           neutral
# 3     3  partial positive
# 4     4          positive
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
category_df = metadata2numbers.get_values_names_keywords(root, "end")
print(category_df)
describe_data.describe_corpus_stackedbars(wdir = wdir, metadata = metadata_recategorized_canon,
class_1 = "decade", class_2 = "end_ordinal", dataset = "CoNSSA-canon", in_proportions= True,
                                          legend = category_df["name"].tolist())
# Out:
#   value              name
# 0     0          negative
# 1     1  partial negative
# 2     2           neutral
# 3     3  partial positive
# 4     4          positive
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
culled_metadata_recategorized = cull_data.cull_metadata(metadata_recategorized, "end_ordinal", ["?","n.av.", None, "unknown","other","mixed","-"])
culled_metadata_recategorized["end_ordinal"] = culled_metadata_recategorized["end_ordinal"].astype(int)
stats.linregress(culled_metadata_recategorized["end_ordinal"], culled_metadata_recategorized["decade"])
# Out:
# LinregressResult(slope=0.557472890797023, intercept=1904.9817086217965, rvalue=0.05269137792349785, pvalue=0.3249507075938476, stderr=0.5655457742169109)

# %%
stats.linregress(culled_metadata_recategorized["end_ordinal"].loc[culled_metadata_recategorized["decade"].isin([1880,1890,1900,1910,1920])], culled_metadata_recategorized["decade"].loc[culled_metadata_recategorized["decade"].isin([1880,1890,1900,1910,1920])])
# Out:
# LinregressResult(slope=0.7292784458834412, intercept=1900.7186401480112, rvalue=0.08117801740885845, pvalue=0.16006721900569557, stderr=0.5178257411299099)
